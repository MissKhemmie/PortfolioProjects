# %%
# import libraries

from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime
import pandas as pd

# %%
 #connect to website

    
url =  'https://www.jumia.com.ng/samsung-galaxy-s22-ultra-single-sim-12gb-ram-256gb-black-268251733.html'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(url)

soup1 = BeautifulSoup(page.content, 'html.parser')

soup2 = BeautifulSoup(soup1.prettify(), 'html.parser')

print(soup2)
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>
#    Samsung Galaxy S22 Ultra Single SIM - 12GB RAM - 256GB - BLACK | Jumia Nigeria
#   </title>
# <meta content="product" property="og:type"/>
# <meta content="Jumia Nigeria" property="og:site_name"/>
# <meta content="Galaxy S22 Ultra Single SIM - 12GB RAM - 256GB - BLACK" property="og:title"/>
# <meta content="Samsung Galaxy S22 Ultra - 6.8\&quot; (12GB RAM, 256GB ROM) Android 12
# (108/12/10/10)MP + 40MP Selfie - Snapdragon 5G  - single sim - 5000mAh The
#  Note that isn\'t a Note, yet it may very well end up being the last Note
#  - Samsung\'s Galaxy S22 Ultra has some big shoes to fill. Attempting to
# appeal to both productivity-focused stylus lovers and photography
# enthusiasts, the latest Ultra will either be the ultimate phone, period,
#  or fall short for either group in some way. We\'re here to find out
# which one is it.The
# ...

# %%
title = soup2.find('title').get_text()
print(title)
# Out:
#    Samsung Galaxy S22 Ultra Single SIM - 12GB RAM - 256GB - BLACK | Jumia Nigeria

# %%
price= soup2.find('span', class_='-b -ltr -tal -fs24 -prxs').get_text()
print(price)
# Out:
#             ₦ 890,300

# %%
Unit_left = soup2.find('p', class_='-df -i-ctr -fs12 -pbs -rd5').get_text().strip()

print(Unit_left)
# Out:
# 2 units left

# %%
#to remove the currency and space
price =price.strip()[1:]
title = title.strip()
print(title)
print(price)
print(Unit_left)
# Out:
# Samsung Galaxy S22 Ultra Single SIM - 12GB RAM - 256GB - BLACK | Jumia Nigeria
#  890,300
# 2 units left

# %%
today = datetime.date.today()
print(today)
# Out:
# 2024-01-20

# %%
import csv

header = ['Title', 'Price', 'Date', 'Units_left']
data = [title, price, today, Unit_left]

with open('Jumia_dataset.csv', 'w', newline= '', encoding ='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
df = pd.read_csv('/Users/oluwakemiayoola/Jumia_dataset.csv')
print(df)
# Out:
#                                                Title     Price        Date    Units_left
# 0  Samsung Galaxy S22 Ultra Single SIM - 12GB RAM...   890,300  2024-01-20  2 units left

# %%
#to fit the output above on a single line
pd.set_option('display.expand_frame_repr', False)

# %%
#Append more data

with open('Jumia_dataset.csv', 'a+', newline= '', encoding ='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
#to get an automated value of the unit left on your computer

def check_unit():
    url =  'https://www.jumia.com.ng/samsung-galaxy-s22-ultra-single-sim-12gb-ram-256gb-black-268251733.html'

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page = requests.get(url)

    soup1 = BeautifulSoup(page.content, 'html.parser')

    soup2 = BeautifulSoup(soup1.prettify(), 'html.parser')
    title = soup2.find('title').get_text()
    price= soup2.find('span', class_='-b -ltr -tal -fs24 -prxs').get_text()
    Unit_left = soup2.find('p', class_='-df -i-ctr -fs12 -pbs -rd5').get_text().strip()
    price =price.strip()[1:]
    title = title.strip()

    today = datetime.date.today()
    import csv

    header = ['Title', 'Price', 'Date', 'Units_left']
    data = [title, price, today, Unit_left]

    with open('Jumia_dataset.csv', 'a+', newline= '', encoding ='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)
    #if (price < '500,000'):
     #   send_mail()

# %%
 while(True):
        check_unit()
        time.sleep(86400)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [110], in <cell line: 2>()
#       1 while(True):
#       2        check_unit()
# ----> 3        time.sleep(86400)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv('/Users/oluwakemiayoola/Jumia_dataset.csv')
print(df)
# Out:
#                                                Title     Price        Date    Units_left
# 0  Samsung Galaxy S22 Ultra Single SIM - 12GB RAM...   890,300  2024-01-20  2 units left
# 1  Samsung Galaxy S22 Ultra Single SIM - 12GB RAM...   890,300  2024-01-20  2 units left
# 2  Samsung Galaxy S22 Ultra Single SIM - 12GB RAM...   890,300  2024-01-20  2 units left
# 3  Samsung Galaxy S22 Ultra Single SIM - 12GB RAM...   890,300  2024-01-20  2 units left
# 4  Samsung Galaxy S22 Ultra Single SIM - 12GB RAM...   890,300  2024-01-20  2 units left
# 5  Samsung Galaxy S22 Ultra Single SIM - 12GB RAM...   890,300  2024-01-20  2 units left
# 6  Samsung Galaxy S22 Ultra Single SIM - 12GB RAM...   890,300  2024-01-20  2 units left
# 7  Samsung Galaxy S22 Ultra Single SIM - 12GB RAM...   890,300  2024-01-20  2 units left
# 8  Samsung Galaxy S22 Ultra Single SIM - 12GB RAM...   890,300  2024-01-20  2 units left
# ...

# %%
# If you want to try sending yourself an email (just for fun) when a unit/price hits below a certain level you can try it
# out with this script

def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('kdelight1027@gmail.com','xxxxxxxxxxxxxx')
    
    subject = "The Phone you want is below   ₦ 500,000! Now is your chance to buy!"
    body = "Kemi, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here:'https://www.jumia.com.ng/samsung-galaxy-s22-ultra-single-sim-12gb-ram-256gb-black-268251733.html"
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'kdelight1027@gmail.com',
        msg
     
    )
